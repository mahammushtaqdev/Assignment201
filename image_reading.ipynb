# %% [markdown]
# <a href="https://colab.research.google.com/github/mahammushtaqdev/Assignment201/blob/main/image_reading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
GEMINI_API_KEY = userdata.get('GOOGLE_API_KEY')

# %%
import google.generativeai as genai

# %%
genai.configure(api_key=GEMINI_API_KEY)

# %%
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
import requests
from PIL import Image
from io import BytesIO
from IPython.display import display

# Replace with the URL of your image
url = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQtYYo5t91q-5NLtEtMwmFqmo2OLqQZRIA0Xw&s'

# Fetch the image from the URL
response = requests.get(url)

# Open the image using PIL
img = Image.open(BytesIO(response.content))

# Display the image inline in Jupyter Notebook
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
prompt = """Describe the image in detail"""



response = model.generate_content([prompt, img])
print(response.text)
# Out:
# That's a lovely digital artwork depicting a polar bear family under a large, luminous moon.
#
#
# Here's a breakdown of the image:
#
# * **The Bears:** A large adult polar bear stands upright on a small ice floe, its head tilted upwards towards a massive, brightly lit moon. Two smaller polar bear cubs sit nestled beside the adult, facing the same direction. The bears are rendered realistically, with attention to detail in their fur texture and body posture.
#
# * **The Moon:** The moon dominates a significant portion of the upper right quadrant of the image. It's significantly larger than a typical moon would appear, suggesting artistic license for dramatic effect. Its surface is detailed, though not photorealistic, with subtle shading and texturing. It emits a soft, warm glow that illuminates the scene.
#
# ...
